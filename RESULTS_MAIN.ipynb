# %%
import joblib
import os
import sys
from visualization import *

# %matplotlib inline

# %%
# Aggregate run results
# !python agg_stats.py
# Out:
# Traceback (most recent call last):
#   File "/home/leostre/Рабочий стол/py-boost/sketchboost-paper/agg_stats.py", line 117, in <module>
#     sub = get_stat(fold)
#   File "/home/leostre/Рабочий стол/py-boost/sketchboost-paper/agg_stats.py", line 75, in get_stat
#     stat, valid = get_result(fold, attr)
#   File "/home/leostre/Рабочий стол/py-boost/sketchboost-paper/agg_stats.py", line 9, in get_result
#     files = os.listdir(folder)
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/SKETCHBOOST_ALLK/dionis/pb/raw_10000'

# %%
nm_d = {
    
    'otto': 'Otto (9 classes)',
    'sf-crime': 'SF-Crime (39 classes)',
    
    'helena': 'Helena (100 classes)',
    'moa': 'MoA (206 labels)',
    'dionis': 'Dionis (355 classes)',
    
    'delicious': 'Delicious (983 labels)',
    'mediamill': 'Mediamill (101 labels)',
    
    'rf1': 'RF1 (8 tasks)',
    'scm20d': 'SCM20D (16 tasks)',
    
}

st_d = {
    'xgb': 'XGBoost (one-vs-all)',
    'cb': 'CatBoost (multioutput)',
    'pb': 'SketchBoost Full',
    'random': 'Random Sampling',
    'best': 'Top Outputs',
    'proj': 'Random Projection',   
}

HYPERPARAMS = 'baselines_and_params.pkl'

dataset_order = ['otto', 'dionis', 'helena', 'sf-crime', 'moa', 'moa', 'scm20d', 'rf1', 'delicious', 'mediamill',]

strategy_order =  ['best', 'random', 'proj',]
baselines = ['pb', 'cb', 'xgb']
k_limit = 20

OUTPUT_DIR = 'output/OUTPUT_MAIN'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
detailed_plot(dataset_order, 
              strategy_order, 
              'test_score', st_d, nm_d, baselines=baselines, alias='Test Error', output_dir=OUTPUT_DIR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 detailed_plot(dataset_order,
#       2               strategy_order,
#       3               'test_score', st_d, nm_d, baselines=baselines, alias='Test Error', output_dir=OUTPUT_DIR)
#
# File ~/Рабочий стол/py-boost/sketchboost-paper/visualization.py:22, in detailed_plot(dataset_order, strategy_order, attr, st_d, nm_d, alias, legend, baselines, k_limit, output_dir)
#      20 plt.figure(figsize=(7, 5))
#      21 for strategy in strategy_order:
# ---> 22     tt = joblib.load(os.path.join('agg', ds, strategy + '.pkl'))[attr]
#      24     tt = tt[tt.index <= k_limit]
#      25     tt.name = st_d[strategy]
#
# File ~/Рабочий стол/py-boost/.venv/lib/python3.10/site-packages/joblib/numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File ~/Рабочий стол/py-boost/.venv/lib/python3.10/site-packages/joblib/numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)
#     633             stacklevel=3,
#     634         )
#
# File /usr/lib/python3.10/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File /usr/lib/python3.10/pickle.py:1590, in _Unpickler.load_reduce(self)
#    1588 args = stack.pop()
#    1589 func = stack[-1]
# -> 1590 stack[-1] = func(*args)
#
# File ~/Рабочий стол/py-boost/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2801, in new_block(values, placement, ndim, refs)
#    2789 def new_block(
#    2790     values,
#    2791     placement: BlockPlacement,
#    (...)
#    2798     # - check_ndim/ensure_block_shape already checked
#    2799     # - maybe_coerce_values already called/unnecessary
#    2800     klass = get_block_type(values.dtype)
# -> 2801     return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# TypeError: Argument 'placement' has incorrect type (expected pandas._libs.internals.BlockPlacement, got slice)

# %%
scores = get_summary_table(dataset_order, strategy_order, 'test_score', 
                           st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)
stds = get_summary_table(dataset_order, strategy_order, 'std_test_score', 
                         st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)


scores = scores.set_index('Dataset').astype(str)


total = (scores + '+-' + stds.set_index('Dataset').astype(str)
         ).replace('-+--', '-').reset_index()
total.to_csv(os.path.join(OUTPUT_DIR, 'summary_' + 'score_w_std' + '.csv'), index=False)

total
# Out:
#                   Dataset SketchBoost Full CatBoost (multioutput)  \
# 0        Otto (9 classes)    0.4697+-0.003         0.4658+-0.0033
# 1    Dionis (355 classes)   0.3114+-0.0009          0.3085+-0.001
# 2    Helena (100 classes)   2.5865+-0.0025         2.5698+-0.0025
# 3   SF-Crime (39 classes)   2.2067+-0.0003         2.2036+-0.0005
# 4        MoA (206 labels)       0.016+-0.0            0.0161+-0.0
# 5       SCM20D (16 tasks)  91.0142+-0.3397        90.9814+-0.3652
# 6           RF1 (8 tasks)   1.1687+-0.0835         0.8975+-0.0384
# 7  Delicious (983 labels)   0.0619+-0.0001         0.0614+-0.0001
# 8  Mediamill (101 labels)   0.0747+-0.0001         0.0754+-0.0001
#
#   XGBoost (one-vs-all)      Top Outputs  Random Sampling Random Projection
# 0       0.4599+-0.0028   0.4715+-0.0035   0.4636+-0.0026    0.4566+-0.0023
# 1        0.3502+-0.002   0.3146+-0.0011    0.304+-0.0014    0.2848+-0.0012
# 2       2.5889+-0.0032   2.5923+-0.0024   2.5693+-0.0022    2.5673+-0.0026
# 3       2.2208+-0.0008    2.207+-0.0005   2.2037+-0.0004    2.2038+-0.0004
# 4                    -      0.0163+-0.0       0.016+-0.0        0.016+-0.0
# 5                    -  88.7442+-0.6346  86.2964+-0.4398   85.8061+-0.5534
# 6                    -    1.186+-0.1366   0.9944+-0.1015    0.9056+-0.0582
# 7                    -   0.0622+-0.0001   0.0619+-0.0001     0.062+-0.0001
# 8                    -   0.0745+-0.0001   0.0745+-0.0001    0.0743+-0.0001

# %%
scores = get_summary_table(dataset_order, strategy_order, 'test_acc', 
                           st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)
stds = get_summary_table(dataset_order, strategy_order, 'std_test_acc', 
                         st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)


scores = scores.set_index('Dataset').astype(str)


total = (scores + '+-' + stds.set_index('Dataset').astype(str)
         ).replace('-+--', '-').reset_index()
total.to_csv(os.path.join(OUTPUT_DIR, 'summary_' + 'acc_w_std' + '.csv'), index=False)

total
# Out:
#                   Dataset SketchBoost Full CatBoost (multioutput)  \
# 0        Otto (9 classes)   0.8223+-0.0021         0.8213+-0.0012
# 1    Dionis (355 classes)   0.9227+-0.0004         0.9234+-0.0003
# 2    Helena (100 classes)   0.3783+-0.0011         0.3808+-0.0017
# 3   SF-Crime (39 classes)   0.3343+-0.0007         0.3352+-0.0008
# 4        MoA (206 labels)      0.9971+-0.0            0.9971+-0.0
# 5       SCM20D (16 tasks)   0.9224+-0.0007         0.9224+-0.0006
# 6           RF1 (8 tasks)   0.9995+-0.0001            0.9997+-0.0
# 7  Delicious (983 labels)      0.9824+-0.0            0.9825+-0.0
# 8  Mediamill (101 labels)   0.9747+-0.0001         0.9744+-0.0001
#
#   XGBoost (one-vs-all)     Top Outputs Random Sampling Random Projection
# 0        0.8238+-0.001   0.821+-0.0016  0.8236+-0.0025     0.8258+-0.001
# 1       0.9193+-0.0007  0.9227+-0.0007  0.9251+-0.0005    0.9285+-0.0004
# 2        0.377+-0.0012  0.3773+-0.0014  0.3821+-0.0009    0.3836+-0.0019
# 3       0.3326+-0.0003  0.3349+-0.0006  0.3353+-0.0005    0.3357+-0.0004
# 4                    -     0.9971+-0.0     0.9972+-0.0       0.9971+-0.0
# 5                    -   0.9262+-0.001  0.9301+-0.0007    0.9309+-0.0008
# 6                    -  0.9994+-0.0001  0.9996+-0.0001       0.9997+-0.0
# 7                    -     0.9824+-0.0     0.9824+-0.0       0.9824+-0.0
# 8                    -     0.9747+-0.0  0.9746+-0.0001       0.9748+-0.0

# %%
get_summary_table(dataset_order, strategy_order, 'best_iter', 
                           st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)
# Out:
#                   Dataset  SketchBoost Full  CatBoost (multioutput)  \
# 0        Otto (9 classes)            4424.8                  5534.4
# 1    Dionis (355 classes)           18519.0                 19858.8
# 2    Helena (100 classes)           13492.2                 11238.2
# 3   SF-Crime (39 classes)            3754.6                  3993.6
# 4        MoA (206 labels)            2240.6                  4239.0
# 5       SCM20D (16 tasks)           19992.8                 19998.0
# 6           RF1 (8 tasks)           17001.4                 19999.0
# 7  Delicious (983 labels)            6911.2                  3956.0
# 8  Mediamill (101 labels)           17927.4                  8983.2
#
#   XGBoost (one-vs-all)  Top Outputs  Random Sampling  Random Projection
# 0               2142.0       4799.2           5424.4             5201.4
# 1               2681.0      17039.4          17990.4            11509.6
# 2               1563.8      15042.0          16975.6            11670.2
# 3               1212.4       3790.2           3726.2             3611.4
# 4                    -       2606.2           5542.6             2093.0
# 5                    -      19992.4          19991.8            19993.6
# 6                    -      16102.8          17076.2            16815.2
# 7                    -       7063.2           8015.0             7541.6
# 8                    -      18623.8          19961.6            17826.6

# %%
get_summary_table(dataset_order, strategy_order, 'train_time', 
                           st_d, nm_d, baselines=baselines, output_dir=OUTPUT_DIR)
# Out:
#                   Dataset  SketchBoost Full  CatBoost (multioutput)  \
# 0        Otto (9 classes)          131.2795                 73.7665
# 1    Dionis (355 classes)        23919.0901              18600.3721
# 2    Helena (100 classes)          355.5974                436.6722
# 3   SF-Crime (39 classes)         1146.1403                659.7310
# 4        MoA (206 labels)          696.2490               9398.4015
# 5       SCM20D (16 tasks)          597.8406                798.6409
# 6           RF1 (8 tasks)          413.7743                804.6936
# 7  Delicious (983 labels)        19553.5613              20120.1416
# 8  Mediamill (101 labels)         1777.6927              10164.0577
#
#   XGBoost (one-vs-all)  Top Outputs  Random Sampling  Random Projection
# 0            1244.9438     113.7105         102.3624            89.6285
# 1           18635.1964    1889.2980        2038.0721           419.5824
# 2            1036.0248     154.6307         180.6419           113.4900
# 3            4016.9352     705.4014         676.2324           612.8040
# 4                    -     103.5214         189.2574            87.0725
# 5                    -     499.3633         528.8417           479.0236
# 6                    -     369.8712         396.4812           340.9701
# 7                    -     575.1124         664.0449          1259.7520
# 8                    -     251.4459         263.4639           294.3931

# %%
scores = get_total_table(dataset_order, strategy_order, 'test_score', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)
stds = get_total_table(dataset_order, strategy_order, 'std_test_score', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)


scores = scores.set_index(['Dataset', 'K']).astype(str)
stds = stds.set_index(['Dataset', 'K']).astype(str)

total = (scores + '+-' + stds).replace('-+--', '-').reset_index()
total.to_csv(os.path.join(OUTPUT_DIR, 'detailed_' + 'test_score_w_std' + '.csv'), index=False)
total
# Out:
#                    Dataset   K Otto (9 classes) Dionis (355 classes)  \
# 0         SketchBoost Full   -    0.4697+-0.003       0.3114+-0.0009
# 1     XGBoost (one-vs-all)   -   0.4599+-0.0028        0.3502+-0.002
# 2   CatBoost (multioutput)   -   0.4658+-0.0033        0.3085+-0.001
# 3              Top Outputs   1   0.4975+-0.0031       0.3339+-0.0017
# 4              Top Outputs   2   0.4964+-0.0042       0.3217+-0.0019
# 5              Top Outputs   5   0.4715+-0.0035       0.3155+-0.0014
# 6              Top Outputs  10                -       0.3151+-0.0014
# 7              Top Outputs  20                -       0.3146+-0.0011
# 8          Random Sampling   1    0.4677+-0.002       0.3175+-0.0009
# 9          Random Sampling   2   0.4636+-0.0026       0.3089+-0.0013
# 10         Random Sampling   5    0.4642+-0.002       0.3055+-0.0012
# 11         Random Sampling  10                -        0.3051+-0.001
# 12         Random Sampling  20                -        0.304+-0.0014
# 13       Random Projection   1   0.4566+-0.0023       0.2848+-0.0012
# 14       Random Projection   2   0.4583+-0.0029        0.285+-0.0011
# 15       Random Projection   5   0.4607+-0.0032       0.2866+-0.0014
# 16       Random Projection  10                -        0.2881+-0.001
# 17       Random Projection  20                -        0.2907+-0.001
#
#    Helena (100 classes) SF-Crime (39 classes) MoA (206 labels)  \
# 0        2.5865+-0.0025        2.2067+-0.0003       0.016+-0.0
# 1        2.5889+-0.0032        2.2208+-0.0008                -
# 2        2.5698+-0.0025        2.2036+-0.0005      0.0161+-0.0
# 3        2.5923+-0.0024        2.2282+-0.0004      0.0169+-0.0
# 4        2.5938+-0.0026        2.2284+-0.0002      0.0168+-0.0
# 5        2.5974+-0.0019        2.2183+-0.0005      0.0168+-0.0
# 6         2.5987+-0.002        2.2116+-0.0003      0.0166+-0.0
# 7         2.5945+-0.002         2.207+-0.0005      0.0163+-0.0
# 8        2.5693+-0.0022         2.214+-0.0004      0.0163+-0.0
# 9         2.571+-0.0032        2.2083+-0.0003      0.0162+-0.0
# 10        2.573+-0.0025        2.2052+-0.0005      0.0161+-0.0
# 11       2.5757+-0.0019        2.2041+-0.0005      0.0161+-0.0
# 12       2.5759+-0.0024        2.2037+-0.0004       0.016+-0.0
# 13        2.5674+-0.004        2.2096+-0.0005       0.016+-0.0
# 14       2.5673+-0.0026        2.2076+-0.0006       0.016+-0.0
# 15       2.5681+-0.0019        2.2052+-0.0006       0.016+-0.0
# 16       2.5713+-0.0024        2.2043+-0.0003       0.016+-0.0
# 17        2.573+-0.0031        2.2038+-0.0004       0.016+-0.0
#
#    SCM20D (16 tasks)   RF1 (8 tasks) Delicious (983 labels)  \
# 0    91.0142+-0.3397  1.1687+-0.0835         0.0619+-0.0001
# 1                  -               -                      -
# 2    90.9814+-0.3652  0.8975+-0.0384         0.0614+-0.0001
# 3    90.7613+-0.3989  1.3151+-0.0721         0.0624+-0.0001
# 4    89.5284+-0.8352  1.2823+-0.1364         0.0624+-0.0001
# 5    88.7442+-0.6346   1.186+-0.1366         0.0623+-0.0001
# 6    89.8727+-0.3126               -         0.0622+-0.0001
# 7                  -               -         0.0622+-0.0001
# 8    87.9358+-0.4112  1.1495+-0.0674         0.0622+-0.0001
# 9    86.7842+-0.5547  0.9965+-0.1012         0.0621+-0.0001
# 10   86.2964+-0.4398  0.9944+-0.1015          0.062+-0.0001
# 11    86.6865+-0.283               -         0.0619+-0.0001
# 12                 -               -         0.0619+-0.0001
# 13   86.1442+-0.4824  0.9058+-0.0442         0.0621+-0.0001
# 14   85.8061+-0.5534  0.9056+-0.0582         0.0621+-0.0001
# 15   85.8565+-0.3116  0.9193+-0.0781          0.062+-0.0001
# 16    86.3126+-0.371               -          0.062+-0.0001
# 17                 -               -          0.062+-0.0001
#
#    Mediamill (101 labels)
# 0          0.0747+-0.0001
# 1                       -
# 2          0.0754+-0.0001
# 3          0.0745+-0.0001
# 4          0.0745+-0.0001
# 5          0.0745+-0.0001
# 6          0.0746+-0.0001
# 7          0.0747+-0.0001
# 8          0.0745+-0.0001
# 9          0.0745+-0.0001
# 10         0.0745+-0.0001
# 11         0.0745+-0.0001
# 12         0.0745+-0.0001
# 13         0.0743+-0.0001
# 14         0.0743+-0.0001
# 15         0.0743+-0.0001
# 16         0.0743+-0.0001
# 17         0.0743+-0.0001

# %%
scores = get_total_table(dataset_order, strategy_order, 'test_acc', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)
stds = get_total_table(dataset_order, strategy_order, 'std_test_acc', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)


scores = scores.set_index(['Dataset', 'K']).astype(str)
stds = stds.set_index(['Dataset', 'K']).astype(str)

total = (scores + '+-' + stds).replace('-+--', '-').reset_index()
total.to_csv(os.path.join(OUTPUT_DIR, 'detailed_' + 'test_acc_w_std' + '.csv'), index=False)
total
# Out:
#                    Dataset   K Otto (9 classes) Dionis (355 classes)  \
# 0         SketchBoost Full   -   0.8223+-0.0021       0.9227+-0.0004
# 1     XGBoost (one-vs-all)   -    0.8238+-0.001       0.9193+-0.0007
# 2   CatBoost (multioutput)   -   0.8213+-0.0012       0.9234+-0.0003
# 3              Top Outputs   1   0.8172+-0.0022       0.9192+-0.0006
# 4              Top Outputs   2   0.8171+-0.0016       0.9214+-0.0004
# 5              Top Outputs   5    0.821+-0.0016       0.9229+-0.0004
# 6              Top Outputs  10                -       0.9229+-0.0003
# 7              Top Outputs  20                -       0.9227+-0.0007
# 8          Random Sampling   1   0.8228+-0.0011       0.9224+-0.0005
# 9          Random Sampling   2   0.8236+-0.0025       0.9243+-0.0003
# 10         Random Sampling   5   0.8231+-0.0018        0.925+-0.0002
# 11         Random Sampling  10                -        0.925+-0.0002
# 12         Random Sampling  20                -       0.9251+-0.0005
# 13       Random Projection   1    0.8258+-0.001       0.9285+-0.0004
# 14       Random Projection   2   0.8255+-0.0023       0.9287+-0.0002
# 15       Random Projection   5   0.8251+-0.0023       0.9281+-0.0002
# 16       Random Projection  10                -       0.9279+-0.0002
# 17       Random Projection  20                -       0.9275+-0.0002
#
#    Helena (100 classes) SF-Crime (39 classes) MoA (206 labels)  \
# 0        0.3783+-0.0011        0.3343+-0.0007      0.9971+-0.0
# 1         0.377+-0.0012        0.3326+-0.0003                -
# 2        0.3808+-0.0017        0.3352+-0.0008      0.9971+-0.0
# 3        0.3773+-0.0014        0.3275+-0.0006       0.997+-0.0
# 4        0.3772+-0.0021        0.3275+-0.0008       0.997+-0.0
# 5         0.376+-0.0019        0.3315+-0.0003       0.997+-0.0
# 6        0.3757+-0.0013        0.3333+-0.0003       0.997+-0.0
# 7        0.3766+-0.0008        0.3349+-0.0006      0.9971+-0.0
# 8        0.3821+-0.0009         0.332+-0.0002      0.9971+-0.0
# 9        0.3827+-0.0015        0.3338+-0.0003      0.9971+-0.0
# 10       0.3795+-0.0022        0.3348+-0.0002      0.9971+-0.0
# 11       0.3793+-0.0018        0.3351+-0.0004      0.9972+-0.0
# 12       0.3795+-0.0017        0.3353+-0.0005      0.9972+-0.0
# 13       0.3834+-0.0033        0.3338+-0.0003      0.9971+-0.0
# 14       0.3836+-0.0019        0.3344+-0.0005      0.9971+-0.0
# 15       0.3835+-0.0018        0.3351+-0.0005      0.9971+-0.0
# 16       0.3824+-0.0022        0.3355+-0.0003      0.9971+-0.0
# 17       0.3805+-0.0025        0.3357+-0.0004      0.9971+-0.0
#
#    SCM20D (16 tasks)   RF1 (8 tasks) Delicious (983 labels)  \
# 0     0.9224+-0.0007  0.9995+-0.0001            0.9824+-0.0
# 1                  -               -                      -
# 2     0.9224+-0.0006     0.9997+-0.0            0.9825+-0.0
# 3     0.9228+-0.0006  0.9992+-0.0001            0.9823+-0.0
# 4     0.9249+-0.0013  0.9993+-0.0001            0.9823+-0.0
# 5      0.9262+-0.001  0.9994+-0.0001            0.9823+-0.0
# 6     0.9243+-0.0005               -            0.9824+-0.0
# 7                  -               -            0.9824+-0.0
# 8     0.9276+-0.0007  0.9995+-0.0001            0.9824+-0.0
# 9     0.9293+-0.0009  0.9996+-0.0001            0.9824+-0.0
# 10    0.9301+-0.0007  0.9996+-0.0001            0.9824+-0.0
# 11    0.9295+-0.0004               -            0.9824+-0.0
# 12                 -               -            0.9824+-0.0
# 13    0.9304+-0.0008     0.9997+-0.0            0.9824+-0.0
# 14    0.9309+-0.0008     0.9997+-0.0            0.9824+-0.0
# 15    0.9308+-0.0005  0.9997+-0.0001            0.9824+-0.0
# 16    0.9301+-0.0006               -            0.9824+-0.0
# 17                 -               -            0.9824+-0.0
#
#    Mediamill (101 labels)
# 0          0.9747+-0.0001
# 1                       -
# 2          0.9744+-0.0001
# 3             0.9747+-0.0
# 4             0.9747+-0.0
# 5          0.9747+-0.0001
# 6             0.9747+-0.0
# 7          0.9747+-0.0001
# 8          0.9746+-0.0001
# 9             0.9746+-0.0
# 10            0.9746+-0.0
# 11            0.9746+-0.0
# 12         0.9746+-0.0001
# 13            0.9747+-0.0
# 14         0.9748+-0.0001
# 15            0.9748+-0.0
# 16            0.9748+-0.0
# 17            0.9747+-0.0

# %%
get_total_table(dataset_order, strategy_order, 'train_time', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)
# Out:
#                    Dataset   K Otto (9 classes)  Dionis (355 classes)  \
# 0         SketchBoost Full   -         131.2795            23919.0901
# 1     XGBoost (one-vs-all)   -        1244.9438            18635.1964
# 2   CatBoost (multioutput)   -          73.7665            18600.3721
# 3              Top Outputs   1         129.5913              783.7018
# 4              Top Outputs   2         126.5449              810.4931
# 5              Top Outputs   5         113.7105             1003.3881
# 6              Top Outputs  10                -             1293.5372
# 7              Top Outputs  20                -             1889.2980
# 8          Random Sampling   1         104.4247              835.5595
# 9          Random Sampling   2         102.3624              880.4566
# 10         Random Sampling   5         116.3004             1087.0867
# 11         Random Sampling  10                -             1404.1419
# 12         Random Sampling  20                -             2038.0721
# 13       Random Projection   1          89.6285              419.5824
# 14       Random Projection   2          87.1467              464.4464
# 15       Random Projection   5          107.955              629.9292
# 16       Random Projection  10                -              895.8915
# 17       Random Projection  20                -             1417.1877
#
#     Helena (100 classes)  SF-Crime (39 classes) MoA (206 labels)  \
# 0               355.5974              1146.1403          696.249
# 1              1036.0248              4016.9352                -
# 2               436.6722               659.7310        9398.4015
# 3               154.6307               174.2330          40.0038
# 4               151.6850               207.5298          45.1278
# 5               146.3063               270.8648          59.4057
# 6               138.1224               425.9713          69.9126
# 7               156.4791               705.4014         103.5214
# 8               180.6419               198.0625          61.5073
# 9               180.9462               219.6978          75.5351
# 10              185.7413               299.7088         104.9205
# 11              198.9258               422.4236         135.0571
# 12              213.2844               676.2324         189.2574
# 13              109.9810               136.5652          26.3955
# 14              113.4900               159.5843          29.3747
# 15              116.9194               233.3936          39.3908
# 16              128.2305               365.4783          55.9317
# 17              149.0080               612.8040          87.0725
#
#    SCM20D (16 tasks) RF1 (8 tasks) Delicious (983 labels)  \
# 0           597.8406      413.7743             19553.5613
# 1                  -             -                      -
# 2           798.6409      804.6936             20120.1416
# 3           458.9562      351.1528               213.8397
# 4           476.2507      364.9863               229.3393
# 5           499.3633      369.8712               274.7669
# 6           551.4483             -               375.7564
# 7                  -             -               575.1124
# 8           485.6434      347.9057                230.644
# 9           491.4076       354.304               243.0265
# 10          528.8417      396.4812               314.3676
# 11          590.4221             -                432.862
# 12                 -             -               664.0449
# 13          466.0371      331.2367                 212.18
# 14          479.0236      340.9701                235.021
# 15           528.448      393.1228               295.0743
# 16          594.7274             -               436.5177
# 17                 -             -               1259.752
#
#    Mediamill (101 labels)
# 0               1777.6927
# 1                       -
# 2              10164.0577
# 3                251.4459
# 4                276.4852
# 5                313.6988
# 6                386.5528
# 7                529.5114
# 8                263.4639
# 9                273.3999
# 10               319.1161
# 11               399.5259
# 12               559.8831
# 13               235.9618
# 14               243.3114
# 15               294.3931
# 16               369.2635
# 17               527.1915

# %%
get_total_table(dataset_order, strategy_order, 'best_iter', 
                         st_d, nm_d, r=4, baselines=baselines, output_dir=OUTPUT_DIR)
# Out:
#                    Dataset   K Otto (9 classes)  Dionis (355 classes)  \
# 0         SketchBoost Full   -           4424.8               18519.0
# 1     XGBoost (one-vs-all)   -           2142.0                2681.0
# 2   CatBoost (multioutput)   -           5534.4               19858.8
# 3              Top Outputs   1           7654.8               17338.8
# 4              Top Outputs   2           7022.8               16747.4
# 5              Top Outputs   5           4799.2               16847.0
# 6              Top Outputs  10                -               16779.4
# 7              Top Outputs  20                -               17039.4
# 8          Random Sampling   1           5937.2               17983.8
# 9          Random Sampling   2           5424.4               17491.6
# 10         Random Sampling   5           4866.0               17799.4
# 11         Random Sampling  10                -               17860.0
# 12         Random Sampling  20                -               17990.4
# 13       Random Projection   1           5201.4               11509.6
# 14       Random Projection   2           4734.0               11486.0
# 15       Random Projection   5           4606.6               12311.0
# 16       Random Projection  10                -               13060.2
# 17       Random Projection  20                -               13672.6
#
#     Helena (100 classes)  SF-Crime (39 classes) MoA (206 labels)  \
# 0                13492.2                 3754.6           2240.6
# 1                 1563.8                 1212.4                -
# 2                11238.2                 3993.6           4239.0
# 3                15042.0                 3467.6           3813.6
# 4                14344.4                 3660.0           3743.6
# 5                13611.8                 3457.6           3613.2
# 6                11975.2                 3699.6           2831.6
# 7                11985.6                 3790.2           2606.2
# 8                16975.6                 3915.8           6161.8
# 9                16823.4                 3809.6           6764.6
# 10               16812.2                 3798.4           6984.8
# 11               17030.4                 3740.8           6288.2
# 12               16232.4                 3726.2           5542.6
# 13               11549.0                 3697.8           2169.6
# 14               11670.2                 3679.2           2121.8
# 15               11701.2                 3620.4           2109.6
# 16               12087.2                 3664.6           2094.4
# 17               12422.6                 3611.4           2093.0
#
#    SCM20D (16 tasks) RF1 (8 tasks) Delicious (983 labels)  \
# 0            19992.8       17001.4                 6911.2
# 1                  -             -                      -
# 2            19998.0       19999.0                 3956.0
# 3            19998.2       17787.6                 7693.6
# 4            19983.6       17431.2                 7439.0
# 5            19992.4       16102.8                 7068.4
# 6            19996.6             -                 7085.6
# 7                  -             -                 7063.2
# 8            19994.6       17230.8                 8134.2
# 9            19991.6       17515.0                 7838.6
# 10           19991.8       17076.2                 8007.2
# 11           19992.8             -                 7994.0
# 12                 -             -                 8015.0
# 13           19994.4       16902.6                 7611.4
# 14           19993.6       16815.2                 7787.6
# 15           19993.4       16766.8                 7613.0
# 16           19987.6             -                 7432.2
# 17                 -             -                 7541.6
#
#    Mediamill (101 labels)
# 0                 17927.4
# 1                       -
# 2                  8983.2
# 3                 18623.8
# 4                 19113.0
# 5                 18447.0
# 6                 17845.4
# 7                 17288.2
# 8                 19961.6
# 9                 19971.6
# 10                19978.6
# 11                19976.0
# 12                19955.2
# 13                18074.4
# 14                18057.0
# 15                17826.6
# 16                17654.6
# 17                17500.0

# %%
hyperparams = joblib.load(os.path.join('runs', HYPERPARAMS))
hyperparams = {x: hyperparams[x] for x in hyperparams if x[0] in dataset_order and x[1] != 'tabnet'}

hp = DataFrame({x: hyperparams[x]['params'] for x in hyperparams}).T
hp['Completed Trials'] = Series({x: hyperparams[x]['num_trials'] for x in hyperparams})
hp.index.names = ('Dataset', 'Framework')
hp = hp.reset_index()
hp['Dataset'] = hp['Dataset'].map(nm_d).map(lambda x: x.split(' ')[0])
hp['Framework'] = hp['Framework'].map(st_d).map(lambda x: x.split(' ')[0])
hp.to_csv(os.path.join(OUTPUT_DIR, 'hyper.csv'), index=False)
hp
# Out:
#       Dataset Framework  min_data_in_leaf  subsample  max_depth  lambda_l2  \
# 0        Otto  CatBoost         47.000000   0.889871       10.0   3.830034
# 1        Otto   XGBoost          0.000010   0.580116       12.0  23.569951
# 2      Dionis  CatBoost          1.000000   1.000000        6.0   1.000000
# 3      Dionis   XGBoost          0.000010   1.000000        6.0   1.000000
# 4      Helena  CatBoost          2.000000   0.546926        6.0  12.773937
# 5      Helena   XGBoost          0.337340   0.504766        6.0  23.325277
# 6    SF-Crime  CatBoost          2.000000   0.941623       11.0   2.646515
# 7    SF-Crime   XGBoost          1.256824   0.918289       12.0   8.374243
# 8         MoA  CatBoost         30.000000   0.880233        4.0   1.031856
# 9      SCM20D  CatBoost          5.000000   0.992114       12.0   6.572463
# 10        RF1  CatBoost          1.000000   0.852105       10.0   9.960692
# 11  Delicious  CatBoost         76.000000   0.623613       12.0  13.057198
# 12  Mediamill  CatBoost         10.000000   0.761407        8.0  11.162539
#
#     Completed Trials
# 0                 31
# 1                 31
# 2                  6
# 3                  3
# 4                 31
# 5                 31
# 6                 31
# 7                 24
# 8                 10
# 9                 31
# 10                31
# 11                 5
# 12                 8

# %%
# !rm {os.path.join(OUTPUT_DIR, 'experiments_main.tar')}
# !tar --totals -cvf {os.path.join(OUTPUT_DIR, 'experiments_main.tar')} {OUTPUT_DIR}
# Out:
# output/OUTPUT_MAIN/
# output/OUTPUT_MAIN/detailed_test_score/
# output/OUTPUT_MAIN/detailed_test_score/otto.png
# output/OUTPUT_MAIN/detailed_test_score/dionis.png
# output/OUTPUT_MAIN/detailed_test_score/helena.png
# output/OUTPUT_MAIN/detailed_test_score/sf-crime.png
# output/OUTPUT_MAIN/detailed_test_score/moa.png
# output/OUTPUT_MAIN/detailed_test_score/scm20d.png
# output/OUTPUT_MAIN/detailed_test_score/rf1.png
# output/OUTPUT_MAIN/detailed_test_score/delicious.png
# output/OUTPUT_MAIN/detailed_test_score/mediamill.png
# output/OUTPUT_MAIN/summary_test_score.csv
# output/OUTPUT_MAIN/summary_std_test_score.csv
# output/OUTPUT_MAIN/summary_score_w_std.csv
# output/OUTPUT_MAIN/summary_test_acc.csv
# output/OUTPUT_MAIN/summary_std_test_acc.csv
# output/OUTPUT_MAIN/summary_acc_w_std.csv
# output/OUTPUT_MAIN/summary_best_iter.csv
# output/OUTPUT_MAIN/summary_train_time.csv
# output/OUTPUT_MAIN/detailed_test_score.csv
# output/OUTPUT_MAIN/detailed_std_test_score.csv
# output/OUTPUT_MAIN/detailed_test_score_w_std.csv
# output/OUTPUT_MAIN/detailed_test_acc.csv
# output/OUTPUT_MAIN/detailed_std_test_acc.csv
# output/OUTPUT_MAIN/detailed_test_acc_w_std.csv
# output/OUTPUT_MAIN/detailed_train_time.csv
# output/OUTPUT_MAIN/detailed_best_iter.csv
# output/OUTPUT_MAIN/hyper.csv
# tar: output/OUTPUT_MAIN/experiments_main.tar: file is the archive; not dumped
# output/OUTPUT_MAIN/hyper_tab.csv
# output/OUTPUT_MAIN/summary_test_pred_time.csv
# Total bytes written: 2785280 (2.7MiB, 129MiB/s)
